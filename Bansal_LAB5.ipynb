# %%
import pandas as pd
import numpy as np

# %%
stu_df=pd.read_csv('student-mat.csv')

# %%
stu_df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
stu_df['school']
# Out:
# 0      GP
# 1      GP
# 2      GP
# 3      GP
# 4      GP
#        ..
# 390    MS
# 391    MS
# 392    MS
# 393    MS
# 394    MS
# Name: school, Length: 395, dtype: object

# %%
#school
stu_df["school"]= np.where(stu_df["school"]=="GP", 1, 0)

# %%
stu_df["school"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 390    0
# 391    0
# 392    0
# 393    0
# 394    0
# Name: school, Length: 395, dtype: int32

# %%
#sex
stu_df['sex']=np.where(stu_df['sex']=='F',1,0)

# %%
stu_df
# Out:
#      school  sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0         1    1   18       U     GT3       A     4     4   at_home   teacher
# 1         1    1   17       U     GT3       T     1     1   at_home     other
# 2         1    1   15       U     LE3       T     1     1   at_home     other
# 3         1    1   15       U     GT3       T     4     2    health  services
# 4         1    1   16       U     GT3       T     3     3     other     other
# ..      ...  ...  ...     ...     ...     ...   ...   ...       ...       ...
# 390       0    0   20       U     LE3       A     2     2  services  services
# 391       0    0   17       U     LE3       T     3     1  services  services
# 392       0    0   21       R     GT3       T     1     1     other     other
# 393       0    0   18       R     LE3       T     3     2  services     other
# 394       0    0   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
stu_df['address'].value_counts()
# Out:
# U    307
# R     88
# Name: address, dtype: int64

# %%
stu_df['address']=np.where(stu_df['address']=='U',1,0)

# %%
stu_df['address']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 390    1
# 391    1
# 392    0
# 393    0
# 394    1
# Name: address, Length: 395, dtype: int32

# %%
#famsize
stu_df['famsize'].value_counts()
# Out:
# GT3    281
# LE3    114
# Name: famsize, dtype: int64

# %%
stu_df['famsize']=np.where(stu_df['famsize']=='GT3',1,0)

# %%
#pstatus
stu_df['Pstatus'].value_counts()
# Out:
# T    354
# A     41
# Name: Pstatus, dtype: int64

# %%
stu_df['Pstatus']=np.where(stu_df['Pstatus']=='T',1,0)

# %%
stu_df['Mjob']
# Out:
# 0       at_home
# 1       at_home
# 2       at_home
# 3        health
# 4         other
#          ...
# 390    services
# 391    services
# 392       other
# 393    services
# 394       other
# Name: Mjob, Length: 395, dtype: object

# %%
#Mjob
stu_df=pd.get_dummies(stu_df, columns=["Mjob"], prefix=["Mjob"])

# %%
#Fjob
stu_df=pd.get_dummies(stu_df, columns=["Fjob"], prefix=["Fjob"])

# %%
stu_df
# Out:
#      school  sex  age  address  famsize  Pstatus  Medu  Fedu  reason guardian  \
# 0         1    1   18        1        1        0     4     4  course   mother
# 1         1    1   17        1        1        1     1     1  course   father
# 2         1    1   15        1        0        1     1     1   other   mother
# 3         1    1   15        1        1        1     4     2    home   mother
# 4         1    1   16        1        1        1     3     3    home   father
# ..      ...  ...  ...      ...      ...      ...   ...   ...     ...      ...
# 390       0    0   20        1        0        0     2     2  course    other
# 391       0    0   17        1        0        1     3     1  course   mother
# 392       0    0   21        0        1        1     1     1  course    other
# 393       0    0   18        0        0        1     3     2  course   mother
# 394       0    0   19        1        0        1     1     1  course   father
#
# ...

# %%
#reason

stu_df=pd.get_dummies(stu_df, columns=["reason"], prefix=["reason"])

# %%
stu_df.shape
# Out:
# (395, 42)

# %%
#guardian
stu_df=pd.get_dummies(stu_df, columns=["guardian"], prefix=["guardian"])

# %%
stu_df.shape
# Out:
# (395, 44)

# %%
#schoolup
stu_df['schoolsup'].value_counts()
# Out:
# no     344
# yes     51
# Name: schoolsup, dtype: int64

# %%
stu_df['schoolsup']=np.where(stu_df['schoolsup']=='no',1,0)

# %%
#famsize
stu_df['famsup'].value_counts()
# Out:
# yes    242
# no     153
# Name: famsup, dtype: int64

# %%
stu_df['famsup']=np.where(stu_df['famsup']=='no',1,0)

# %%
#paid
stu_df['paid'].value_counts()
# Out:
# no     214
# yes    181
# Name: paid, dtype: int64

# %%
stu_df['paid']=np.where(stu_df['paid']=='no',1,0)

# %%
#activities
stu_df['activities'].value_counts()
# Out:
# yes    201
# no     194
# Name: activities, dtype: int64

# %%
stu_df['activities']=np.where(stu_df['activities']=='no',1,0)

# %%
#nursery

stu_df['nursery']=np.where(stu_df['nursery']=='yes',1,0)

# %%
#higher
stu_df['higher']=np.where(stu_df['higher']=='yes',1,0)

# %%
#internet
stu_df['internet']=np.where(stu_df['internet']=='yes',1,0)

# %%
#romantic
stu_df['romantic']=np.where(stu_df['romantic']=='no',1,0)

# %%
stu_df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'traveltime', 'studytime', 'failures', 'schoolsup', 'famsup', 'paid',
#        'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel',
#        'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'grade',
#        'Mjob_at_home', 'Mjob_health', 'Mjob_other', 'Mjob_services',
#        'Mjob_teacher', 'Fjob_at_home', 'Fjob_health', 'Fjob_other',
#        'Fjob_services', 'Fjob_teacher', 'reason_course', 'reason_home',
#        'reason_other', 'reason_reputation', 'guardian_father',
#        'guardian_mother', 'guardian_other'],
#       dtype='object')

# %%
df1 = stu_df.pop('grade')

# %%
df1
# Out:
# 0      F
# 1      F
# 2      C
# 3      B
# 4      C
#       ..
# 390    C
# 391    A
# 392    C
# 393    C
# 394    C
# Name: grade, Length: 395, dtype: object

# %%
stu_df
# Out:
#      school  sex  age  address  famsize  Pstatus  Medu  Fedu  traveltime  \
# 0         1    1   18        1        1        0     4     4           2
# 1         1    1   17        1        1        1     1     1           1
# 2         1    1   15        1        0        1     1     1           1
# 3         1    1   15        1        1        1     4     2           1
# 4         1    1   16        1        1        1     3     3           1
# ..      ...  ...  ...      ...      ...      ...   ...   ...         ...
# 390       0    0   20        1        0        0     2     2           1
# 391       0    0   17        1        0        1     3     1           2
# 392       0    0   21        0        1        1     1     1           1
# 393       0    0   18        0        0        1     3     2           3
# 394       0    0   19        1        0        1     1     1           1
#
#      studytime  ...  Fjob_other  Fjob_services  Fjob_teacher  reason_course  \
# ...

# %%
stu_df['grade']=df1

# %%
stu_df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'traveltime', 'studytime', 'failures', 'schoolsup', 'famsup', 'paid',
#        'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel',
#        'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences',
#        'Mjob_at_home', 'Mjob_health', 'Mjob_other', 'Mjob_services',
#        'Mjob_teacher', 'Fjob_at_home', 'Fjob_health', 'Fjob_other',
#        'Fjob_services', 'Fjob_teacher', 'reason_course', 'reason_home',
#        'reason_other', 'reason_reputation', 'guardian_father',
#        'guardian_mother', 'guardian_other', 'grade'],
#       dtype='object')

# %%
X = stu_df.iloc[:,:-1]
y = stu_df.iloc[:,-1]

# %%
X
# Out:
#      school  sex  age  address  famsize  Pstatus  Medu  Fedu  traveltime  \
# 0         1    1   18        1        1        0     4     4           2
# 1         1    1   17        1        1        1     1     1           1
# 2         1    1   15        1        0        1     1     1           1
# 3         1    1   15        1        1        1     4     2           1
# 4         1    1   16        1        1        1     3     3           1
# ..      ...  ...  ...      ...      ...      ...   ...   ...         ...
# 390       0    0   20        1        0        0     2     2           1
# 391       0    0   17        1        0        1     3     1           2
# 392       0    0   21        0        1        1     1     1           1
# 393       0    0   18        0        0        1     3     2           3
# 394       0    0   19        1        0        1     1     1           1
#
#      studytime  ...  Fjob_other  Fjob_services  Fjob_teacher  reason_course  \
# ...

# %%
X.shape
# Out:
# (395, 43)

# %%
y.shape
# Out:
# (395,)

# %%
y.value_counts()
# Out:
# C    170
# B    103
# F     69
# A     53
# Name: grade, dtype: int64

# %%
y_log = pd.Series([])

# %%
y.shape
# Out:
# (395,)

# %%
for i in range(len(y)):
    if(y[i]=='A' or y[i]=="B" or y[i]=='C'):
        y_log[i]="NotF"
    else:
        y_log[i]="F"

# %%
y_log.shape
# Out:
# (395,)

# %%
from sklearn.model_selection import train_test_split
X_train_log,X_test_log,Y_train_log,Y_test_log=train_test_split(X,y_log,random_state=0,test_size=0.25)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
X_train_s=scaler.fit_transform(X_train_log)
X_test_s=scaler.transform(X_test_log)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
depth = [5]

grid_param = dict(max_depth=depth)
dtree = GridSearchCV(DecisionTreeClassifier(random_state=0), grid_param, cv=5, iid=False, scoring='roc_auc')
dtree.fit(X_train_s, Y_train_log)

print(dtree.best_params_)

print("test accuracy after pass fail conversion",dtree.score(X_test_s,Y_test_log))

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
y_pred_tree = dtree.predict(X_test_s)

print(classification_report(Y_test_log,y_pred_tree))
print(confusion_matrix(Y_test_log,y_pred_tree))
# Out:
# {'max_depth': 5}
# test accuracy after pass fail conversion 0.5086083213773314
#               precision    recall  f1-score   support
#
#            F       0.44      0.24      0.31        17
#         NotF       0.86      0.94      0.90        82
#
#     accuracy                           0.82        99
#    macro avg       0.65      0.59      0.60        99
# weighted avg       0.78      0.82      0.79        99
#
# [[ 4 13]
#  [ 5 77]]
# c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages\sklearn\model_selection\_search.py:823: FutureWarning: The parameter 'iid' is deprecated in 0.22 and will be removed in 0.24.
#   "removed in 0.24.", FutureWarning

# %% [markdown]
# # Logistic Regression Mulitiple

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,y,random_state=0,test_size=0.20)

from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
logistic= LogisticRegression(solver='lbfgs',multi_class='auto',max_iter=1000,random_state=0)

# %%
logistic.fit(X_train,Y_train)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, recall_score
y_pred = logistic.predict(X_test)
print(confusion_matrix(Y_test,y_pred))

# %%
print(classification_report(Y_test,y_pred))

# %%
print(recall_score(Y_test, y_pred, average='micro'))
