# %%
#Assigmnet - 1 Machine Learning

# %%
import pandas as pd
studf = pd.read_csv('student-mat.csv', index_col = 0) #original columns from csv will be loaded as columns
studf.head()
# Out:
#        sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# school
# GP       F   18       U     GT3       A     4     4  at_home   teacher
# GP       F   17       U     GT3       T     1     1  at_home     other
# GP       F   15       U     LE3       T     1     1  at_home     other
# GP       F   15       U     GT3       T     4     2   health  services
# GP       F   16       U     GT3       T     3     3    other     other
#
#         reason  ... internet  romantic  famrel  freetime goout Dalc Walc  \
# school          ...
# GP      course  ...       no        no       4         3     4    1    1
# GP      course  ...      yes        no       5         3     3    1    1
# GP       other  ...      yes        no       4         3     2    2    3
# GP        home  ...      yes       yes       3         2     2    1    1
# GP        home  ...       no        no       4         3     2    1    2
#
#        health absences grade
# school
# GP          3        6     F
# ...

# %%
studf.head()
# Out:
#     age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  reason  \
# sex
# F     F       U     GT3       A     4     4  at_home   teacher  course
# F     F       U     GT3       T     1     1  at_home     other  course
# F     F       U     LE3       T     1     1  at_home     other   other
# F     F       U     GT3       T     4     2   health  services    home
# F     F       U     GT3       T     3     3    other     other    home
#
#     guardian  ...  internet  romantic  famrel freetime goout Dalc Walc health  \
# sex           ...
# F     mother  ...        no        no       4        3     4    1    1      3
# F     father  ...       yes        no       5        3     3    1    1      3
# F     mother  ...       yes        no       4        3     2    2    3      3
# F     mother  ...       yes       yes       3        2     2    1    1      5
# F     father  ...        no        no       4        3     2    1    2      5
#
#     absences grade
# sex
# ...

# %%
studf['age'] = studf.index
studf = studf.set_index('school')
studf.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-27851b69654f> in <module>
#       1 studf['age'] = studf.index
# ----> 2 studf = studf.set_index('school')
#       3 studf.head()
#
# c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4409
#    4410         if missing:
# -> 4411             raise KeyError("None of {} are in the columns".format(missing))
#    4412
#    4413         if inplace:
#
# KeyError: "None of ['school'] are in the columns"

# %%
studf= studf.reset_index()

# %%
studf.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   internet romantic  famrel  freetime  goout Dalc Walc health absences grade
# 0       no       no       4         3      4    1    1      3        6     F
# 1      yes       no       5         3      3    1    1      3        4     F
# 2      yes       no       4         3      2    2    3      3       10     C
# 3      yes      yes       3         2      2    1    1      5        2     B
# 4       no       no       4         3      2    1    2      5        4     C
#
# [5 rows x 31 columns]

# %%
studf.info()
studf.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 31 columns):
# school        395 non-null object
# sex           395 non-null object
# age           395 non-null int64
# address       395 non-null object
# famsize       395 non-null object
# Pstatus       395 non-null object
# Medu          395 non-null int64
# Fedu          395 non-null int64
# Mjob          395 non-null object
# Fjob          395 non-null object
# reason        395 non-null object
# guardian      395 non-null object
# traveltime    395 non-null int64
# studytime     395 non-null int64
# failures      395 non-null int64
# schoolsup     395 non-null object
# famsup        395 non-null object
# paid          395 non-null object
# activities    395 non-null object
# nursery       395 non-null object
# higher        395 non-null object
# internet      395 non-null object
# romantic      395 non-null object
# famrel        395 non-null int64
# ...

# %%
temp = studf[(studf['sex'] == 'F')]
temp[(temp['grade'] == 'B') | (temp['grade']== 'A')]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 15      GP   F   16       U     GT3       T     4     4    health     other
# 16      GP   F   16       U     GT3       T     4     4  services  services
# 39      GP   F   15       R     GT3       T     2     2   at_home     other
# 50      GP   F   16       U     LE3       T     2     2  services  services
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 369     MS   F   18       R     GT3       T     4     4     other   teacher
# 372     MS   F   17       U     GT3       T     2     2     other   at_home
# 374     MS   F   18       R     LE3       T     4     4     other     other
# 376     MS   F   20       U     GT3       T     4     2    health     other
# 378     MS   F   18       U     GT3       T     3     3     other     other
#
# ...

# %%
t1 = studf[(studf['grade']=='A')]
t2 = studf[(studf['grade']=='F')]
ratio = t1.shape[0]/t2.shape[0]
print(t1.shape[0])
print(t2.shape[0])
# Out:
# 53
# 69

# %%
t1=studf[(studf['grade']=='A')]
t1.shape[0]
# Out:
# 53

# %%
conv_dict = {'A':4, 'B':3, 'C':2, 'F':1}
studf['grade_c'] = studf.grade.apply(conv_dict.get)
studf['grade_c'].head()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
t_f = studf[studf['sex']=='F']
print(t_f.head(30))
t_f.describe()
# Out:
#        sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# school
# GP       F   18       U     GT3       A     4     4   at_home   teacher
# GP       F   17       U     GT3       T     1     1   at_home     other
# GP       F   15       U     LE3       T     1     1   at_home     other
# GP       F   15       U     GT3       T     4     2    health  services
# GP       F   16       U     GT3       T     3     3     other     other
# GP       F   17       U     GT3       A     4     4     other   teacher
# GP       F   15       U     GT3       T     4     4   teacher    health
# GP       F   15       U     GT3       T     2     1  services     other
# GP       F   16       U     GT3       T     4     4    health     other
# GP       F   16       U     GT3       T     4     4  services  services
# GP       F   16       U     GT3       T     3     3     other     other
# GP       F   15       R     GT3       T     2     4  services    health
# ...

# %%
# PART B

# %%
nutdf =  pd.read_csv('Nutritional Data for Fast Foods.csv', index_col = 0) #original columns from csv will be loaded as columns
nutdf.head()
# Out:
#   Fast Food Restaurant                         Item    Type  Serving Size (g)  \
# 0           McDonald's                    Hamburger  Burger                98
# 1           McDonald's                 Cheeseburger  Burger               113
# 2           McDonald's                            ?  Burger               211
# 3           McDonald's  Quarter Pounder with Cheese  Burger               202
# 4           McDonald's       Bacon Clubhouse Burger  Burger               270
#
#    Calories  Total Fat (g)  Saturated Fat (g)  Trans Fat (g)  Sodium (mg)  \
# 0       240            8.0                3.0            0.0        480.0
# 1       290           11.0                5.0            0.5        680.0
# 2       530           27.0               10.0            1.0        960.0
# 3       520           26.0               12.0            1.5       1100.0
# 4       720           40.0               15.0            1.5       1470.0
#
#    Carbs (g)  Sugars (g)  Protein (g)
# ...

# %%
nutdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 126 entries, 0 to 125
# Data columns (total 12 columns):
# Fast Food Restaurant    126 non-null object
# Item                    126 non-null object
# Type                    126 non-null object
# Serving Size (g)        126 non-null int64
# Calories                126 non-null int64
# Total Fat (g)           122 non-null float64
# Saturated Fat (g)       126 non-null float64
# Trans Fat (g)           114 non-null float64
# Sodium (mg)             121 non-null float64
# Carbs (g)               126 non-null float64
# Sugars (g)              126 non-null float64
# Protein (g)             122 non-null float64
# dtypes: float64(7), int64(2), object(3)
# memory usage: 12.8+ KB

# %%
count = nutdf['Item'].unique()
c1 = nutdf['Type'].unique()
len(count)
len(c1)
# Out:
# 6

# %%
g_nutdf = nutdf.groupby('Type')
g_nutdf.first()

g_nutdf.get_group('French Fries').describe()
# Out:
#        Serving Size (g)    Calories  Total Fat (g)  Saturated Fat (g)  \
# count         12.000000   12.000000      12.000000          12.000000
# mean         109.500000  314.083333      15.308333           2.891667
# std           24.648437   49.690786       2.778966           1.204128
# min           75.000000  230.000000      11.000000           1.500000
# 25%           85.000000  280.000000      14.000000           2.000000
# 50%          107.500000  315.000000      14.850000           2.600000
# 75%          126.500000  337.500000      17.250000           3.250000
# max          148.000000  395.000000      21.000000           5.000000
#
#        Trans Fat (g)  Sodium (mg)  Carbs (g)  Sugars (g)  Protein (g)
# count           11.0    12.000000  12.000000   12.000000    11.000000
# mean             0.1   375.833333  40.866667    0.191667     3.672727
# std              0.3   258.041869   8.092346    0.575971     1.272078
# ...

# %%
x = g_nutdf.get_group('Burger').max()['Protein (g)']
print(x)
#print(x['Protein (g)'])
#nutdf[(nutdf['Type']=='Burger') & (nutdf['Protein (g)']=='69']
# Out:
# 69.0

# %%
nutdf.head(20)
# Out:
#    Fast Food Restaurant                                Item  \
# 0            McDonald's                           Hamburger
# 1            McDonald's                        Cheeseburger
# 2            McDonald's                                   ?
# 3            McDonald's         Quarter Pounder with Cheese
# 4            McDonald's              Bacon Clubhouse Burger
# 5            McDonald's  Double Quarter Pounder with Cheese
# 6            McDonald's              Chocolate Shake (12oz)
# 7            McDonald's                                   ?
# 8            McDonald's                                   ?
# 9            McDonald's        Chicken McNuggets® (4 piece)
# 10           McDonald's                                   ?
# 11          Burger King                           Hamburger
# 12          Burger King                        Cheeseburger
# 13          Burger King                   WHOPPER® Sandwich
# 14          Burger King    Bacon & Cheese WHOPPER® Sandwich
# ...
