# %%
import keras as tf
tf.__version__
# Out:
# '2.3.1'

# %%
import seaborn as sns

# %%
str = "ABC"

#df = yf.download("MSFT", start="2019-12-01", end="2020-05-07")
$str+df
# Out:
#   File "<ipython-input-47-fd3ba3deb5de>", line 4
#     $str+df
#     ^
# SyntaxError: invalid syntax

# %%
file_A.df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-ced4bb0bd6ea> in <module>
# ----> 1 file_A.df
#
# NameError: name 'file_A' is not defined

# %%
import yfinance as yf
import time
time.sleep(1) 
msft = yf.Ticker("MSFT")

# get stock info
#print(msft.info)

# get historical market data
#hist = msft.history(period="30d")
msft.financials
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
# Download stock data then export as CSV
data_df = yf.download("^GSPC", start="2019-01-01", end="2020-05-07")
data_df.to_csv('s&p.csv')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
from pandas_datareader import data as pdr

import yfinance as yf
yf.pdr_override() # <== that's all it takes :-)

# download dataframe
nasdaq = pdr.get_data_yahoo("^IXIC", start="2019-01-01", end="2020-05-07")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
sns.distplot(nasdaq['Close'])

# %%
uber = pdr.get_data_yahoo("UBER", start="2019-01-01", end="2020-05-07" )
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data_df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-02-03  170.429993  174.500000  170.399994  174.380005  173.904999
# 2020-02-04  177.139999  180.639999  176.309998  180.119995  179.629364
# 2020-02-05  184.029999  184.199997  178.410004  179.899994  179.409958
# 2020-02-06  180.970001  183.820007  180.059998  183.630005  183.129807
# 2020-02-07  182.850006  185.630005  182.479996  183.889999  183.389099
# 2020-02-10  183.580002  188.839996  183.250000  188.699997  188.185989
# 2020-02-11  190.649994  190.699997  183.500000  184.440002  183.937607
# 2020-02-12  185.580002  185.850006  181.850006  184.710007  184.206863
# 2020-02-13  183.080002  186.229996  182.869995  183.710007  183.209595
# 2020-02-14  183.250000  185.410004  182.649994  185.350006  184.845123
# 2020-02-18  185.610001  187.699997  185.500000  187.229996  186.720001
# 2020-02-19  188.059998  188.179993  186.470001  187.279999  187.279999
# ...

# %%
nasdaq['Close'].plot(figsize=(16, 9))

# %%
uber['Close'].plot(figsize=(9,5))

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-83-9ce699d4ae49> in <module>
#       1 real_var_and_price = [uber['Close'],nasdaq['Close']]
# ----> 2 sns.pairplot(data[real_var_and_price])
#
# c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2999             if is_iterator(key):
#    3000                 key = list(key)
# -> 3001             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    3002
#    3003         # take() does not accept boolean indexers
#
# c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
# ...

# %%
import matplotlib.pyplot as plt
import seaborn

# Plot everything by leveraging the very powerful matplotlib package
hist['Close'].plot(figsize=(16, 9))
